# %%
import psycopg2
import os
from dotenv import load_dotenv
load_dotenv()
db_password = os.getenv("DB_PASSWORD")
connection = None

try:
    connection = psycopg2.connect(
        user="postgres",
        password=db_password,
        host="127.0.0.1",
        port="5432",
        database="dvdrental",
    )

    cursor = connection.cursor()
    query = """
            select customer_id, staff_id, sum(amount) from payment
            group by staff_id, customer_id
            order by customer_id, staff_id
            """
    cursor.execute(query)
    rows = cursor.fetchall()
    for row in rows:
        print(row)
except Exception as error:
    print(error)
finally:
    if connection:
        cursor.close()
        connection.close()
        print("PostgreSQL connection is closed")
# Out:
# (1, 1, Decimal('60.85'))
# (1, 2, Decimal('53.85'))
# (2, 1, Decimal('55.86'))
# (2, 2, Decimal('67.88'))
# (3, 1, Decimal('59.88'))
# (3, 2, Decimal('70.88'))
# (4, 1, Decimal('49.88'))
# (4, 2, Decimal('31.90'))
# (5, 1, Decimal('63.86'))
# (5, 2, Decimal('70.79'))
# (6, 1, Decimal('53.85'))
# (6, 2, Decimal('30.90'))
# (7, 1, Decimal('69.84'))
# (7, 2, Decimal('60.88'))
# (8, 1, Decimal('57.86'))
# (8, 2, Decimal('27.91'))
# (9, 1, Decimal('39.88'))
# (9, 2, Decimal('38.92'))
# (10, 1, Decimal('40.88'))
# (10, 2, Decimal('53.88'))
# (11, 1, Decimal('53.88'))
# (11, 2, Decimal('45.89'))
# (12, 1, Decimal('21.92'))
# (12, 2, Decimal('71.82'))
# (13, 1, Decimal('76.83'))
# (13, 2, Decimal('54.90'))
# (14, 1, Decimal('55.84'))
# (14, 2, Decimal('40.93'))
# (15, 1, Decimal('72.82'))
# (15, 2, Decimal('61.86'))
# (16, 1, Decimal('57.90'))
# (16, 2, Decimal('51.85'))
# (17, 1, Decimal('32.91'))
# (17, 2, Decimal('54.91'))
# (18, 1, Decimal('24.95'))
# (18, 2, Decimal('53.86'))
# (19, 1, Decimal('53.90'))
# (19, 2, Decimal('44.92'))
# (20, 1, Decimal('35.89'))
# (20, 2, Decimal('67.84'))
# (21, 1, Decimal('80.84'))
# (21, 2, Decimal('65.84'))
# (22, 1, Decimal('79.85'))
# (22, 2, Decimal('14.96'))
# (23, 1, Decimal('43.89'))
# (23, 2, Decimal('62.84'))
# (24, 1, Decimal('34.88'))
# (24, 2, Decimal('50.89'))
# (25, 1, Decimal('66.83'))
# (25, 2, Decimal('37.90'))
# (26, 1, Decimal('101.79'))
# (26, 2, Decimal('44.89'))
# (27, 1, Decimal('65.85'))
# (27, 2, Decimal('57.85'))
# (28, 1, Decimal('49.87'))
# (28, 2, Decimal('55.83'))
# (29, 1, Decimal('75.80'))
# (29, 2, Decimal('62.85'))
# (30, 1, Decimal('66.82'))
# (30, 2, Decimal('56.84'))
# (31, 1, Decimal('31.90'))
# (31, 2, Decimal('72.84'))
# (32, 1, Decimal('56.87'))
# (32, 2, Decimal('55.87'))
# (33, 1, Decimal('67.85'))
# (33, 2, Decimal('20.95'))
# (34, 1, Decimal('42.87'))
# (34, 2, Decimal('46.89'))
# (35, 1, Decimal('92.78'))
# (35, 2, Decimal('25.92'))
# (36, 1, Decimal('40.90'))
# (36, 2, Decimal('49.85'))
# (37, 1, Decimal('53.89'))
# (37, 2, Decimal('37.90'))
# (38, 1, Decimal('61.84'))
# (38, 2, Decimal('65.82'))
# (39, 1, Decimal('60.87'))
# (39, 2, Decimal('80.84'))
# (40, 1, Decimal('53.87'))
# (40, 2, Decimal('51.87'))
# (41, 1, Decimal('50.88'))
# (41, 2, Decimal('67.87'))
# (42, 1, Decimal('62.84'))
# (42, 2, Decimal('48.87'))
# (43, 1, Decimal('42.90'))
# (43, 2, Decimal('46.88'))
# (44, 1, Decimal('44.90'))
# (44, 2, Decimal('56.89'))
# (45, 1, Decimal('84.84'))
# (45, 2, Decimal('39.90'))
# (46, 1, Decimal('47.86'))
# (46, 2, Decimal('83.83'))
# (47, 1, Decimal('35.91'))
# (47, 2, Decimal('56.90'))
# (48, 1, Decimal('24.95'))
# (48, 2, Decimal('42.91'))
# (49, 1, Decimal('50.88'))
# (49, 2, Decimal('65.88'))
# (50, 1, Decimal('58.88'))
# (50, 2, Decimal('85.82'))
# (51, 1, Decimal('79.80'))
# (51, 2, Decimal('43.90'))
# (52, 1, Decimal('48.87'))
# (52, 2, Decimal('57.85'))
# (53, 1, Decimal('51.88'))
# (53, 2, Decimal('36.88'))
# (54, 1, Decimal('67.85'))
# (54, 2, Decimal('46.89'))
# (55, 1, Decimal('45.90'))
# (55, 2, Decimal('38.91'))
# (56, 1, Decimal('57.87'))
# (56, 2, Decimal('57.87'))
# (57, 1, Decimal('29.89'))
# (57, 2, Decimal('69.85'))
# (58, 1, Decimal('60.87'))
# (58, 2, Decimal('44.89'))
# (59, 1, Decimal('68.86'))
# (59, 2, Decimal('50.90'))
# (60, 1, Decimal('55.86'))
# (60, 2, Decimal('32.92'))
# (61, 1, Decimal('25.94'))
# (61, 2, Decimal('31.93'))
# (62, 1, Decimal('30.90'))
# (62, 2, Decimal('47.89'))
# (63, 1, Decimal('60.88'))
# (63, 2, Decimal('51.87'))
# (64, 1, Decimal('49.85'))
# (64, 2, Decimal('41.85'))
# (65, 1, Decimal('62.89'))
# (65, 2, Decimal('34.91'))
# (66, 1, Decimal('82.81'))
# (66, 2, Decimal('56.86'))
# (67, 1, Decimal('44.92'))
# (67, 2, Decimal('41.88'))
# (68, 1, Decimal('35.90'))
# (68, 2, Decimal('58.88'))
# (69, 1, Decimal('53.87'))
# (69, 2, Decimal('35.90'))
# (70, 1, Decimal('50.89'))
# (70, 2, Decimal('24.94'))
# (71, 1, Decimal('72.84'))
# (71, 2, Decimal('43.88'))
# (72, 1, Decimal('28.89'))
# (72, 2, Decimal('59.84'))
# (73, 1, Decimal('50.88'))
# (73, 2, Decimal('38.90'))
# (74, 1, Decimal('33.90'))
# (74, 2, Decimal('62.84'))
# (75, 1, Decimal('82.80'))
# (75, 2, Decimal('66.81'))
# (76, 1, Decimal('22.95'))
# (76, 2, Decimal('51.84'))
# (77, 1, Decimal('31.90'))
# (77, 2, Decimal('53.87'))
# (78, 1, Decimal('55.87'))
# (78, 2, Decimal('85.82'))
# (79, 1, Decimal('31.90'))
# (79, 2, Decimal('41.91'))
# (80, 1, Decimal('76.85'))
# (80, 2, Decimal('60.85'))
# (81, 1, Decimal('51.87'))
# (81, 2, Decimal('40.92'))
# (82, 1, Decimal('59.89'))
# (82, 2, Decimal('58.87'))
# (83, 1, Decimal('34.91'))
# (83, 2, Decimal('61.87'))
# (84, 1, Decimal('47.90'))
# (84, 2, Decimal('80.80'))
# (85, 1, Decimal('41.88'))
# (85, 2, Decimal('30.91'))
# (86, 1, Decimal('63.86'))
# (86, 2, Decimal('82.82'))
# (87, 1, Decimal('62.85'))
# (87, 2, Decimal('74.87'))
# (88, 1, Decimal('60.87'))
# (88, 2, Decimal('23.93'))
# (89, 1, Decimal('61.85'))
# (89, 2, Decimal('62.86'))
# (90, 1, Decimal('50.88'))
# (90, 2, Decimal('59.84'))
# (91, 1, Decimal('54.84'))
# (91, 2, Decimal('52.82'))
# (92, 1, Decimal('52.86'))
# (92, 2, Decimal('69.88'))
# (93, 1, Decimal('36.89'))
# (93, 2, Decimal('39.91'))
# (94, 1, Decimal('42.90'))
# (94, 2, Decimal('28.91'))
# (95, 1, Decimal('32.93'))
# (95, 2, Decimal('39.90'))
# (96, 1, Decimal('57.84'))
# (96, 2, Decimal('47.89'))
# (97, 1, Decimal('19.92'))
# (97, 2, Decimal('38.90'))
# (98, 1, Decimal('44.89'))
# (98, 2, Decimal('57.87'))
# (99, 1, Decimal('27.90'))
# (99, 2, Decimal('62.87'))
# (100, 1, Decimal('42.89'))
# (100, 2, Decimal('58.88'))
# (101, 1, Decimal('26.92'))
# (101, 2, Decimal('59.85'))
# (102, 1, Decimal('59.88'))
# (102, 2, Decimal('69.82'))
# (103, 1, Decimal('42.86'))
# (103, 2, Decimal('85.85'))
# (104, 1, Decimal('42.87'))
# (104, 2, Decimal('34.91'))
# (105, 1, Decimal('23.94'))
# (105, 2, Decimal('69.84'))
# (106, 1, Decimal('63.87'))
# (106, 2, Decimal('31.92'))
# (107, 1, Decimal('48.89'))
# (107, 2, Decimal('65.83'))
# (108, 1, Decimal('52.86'))
# (108, 2, Decimal('73.86'))
# (109, 1, Decimal('19.94'))
# (109, 2, Decimal('59.87'))
# (110, 1, Decimal('27.93'))
# (110, 2, Decimal('21.95'))
# (111, 1, Decimal('24.94'))
# (111, 2, Decimal('69.81'))
# (112, 1, Decimal('56.87'))
# (112, 2, Decimal('72.85'))
# (113, 1, Decimal('50.87'))
# (113, 2, Decimal('60.86'))
# (114, 1, Decimal('64.83'))
# (114, 2, Decimal('61.87'))
# (115, 1, Decimal('51.88'))
# (115, 2, Decimal('34.85'))
# (116, 1, Decimal('33.89'))
# (116, 2, Decimal('72.85'))
# (117, 1, Decimal('50.88'))
# (117, 2, Decimal('18.95'))
# (118, 1, Decimal('31.89'))
# (118, 2, Decimal('44.91'))
# (119, 1, Decimal('62.87'))
# (119, 2, Decimal('76.82'))
# (120, 1, Decimal('68.86'))
# (120, 2, Decimal('65.84'))
# (121, 1, Decimal('38.90'))
# (121, 2, Decimal('65.85'))
# (122, 1, Decimal('46.86'))
# (122, 2, Decimal('73.84'))
# (123, 1, Decimal('45.88'))
# (123, 2, Decimal('51.89'))
# (124, 1, Decimal('29.94'))
# (124, 2, Decimal('27.92'))
# (125, 1, Decimal('86.80'))
# (125, 2, Decimal('44.89'))
# (126, 1, Decimal('52.87'))
# (126, 2, Decimal('49.88'))
# (127, 1, Decimal('57.89'))
# (127, 2, Decimal('47.89'))
# (128, 1, Decimal('48.88'))
# (128, 2, Decimal('69.82'))
# (129, 1, Decimal('59.82'))
# (129, 2, Decimal('64.84'))
# (130, 1, Decimal('41.89'))
# (130, 2, Decimal('45.89'))
# (131, 1, Decimal('80.82'))
# (131, 2, Decimal('31.91'))
# (132, 1, Decimal('62.84'))
# (132, 2, Decimal('32.88'))
# (133, 1, Decimal('41.88'))
# (133, 2, Decimal('46.87'))
# (134, 1, Decimal('45.92'))
# (134, 2, Decimal('31.89'))
# (135, 1, Decimal('52.83'))
# (135, 2, Decimal('47.89'))
# (136, 1, Decimal('27.94'))
# (136, 2, Decimal('31.92'))
# (137, 1, Decimal('112.78'))
# (137, 2, Decimal('78.84'))
# (138, 1, Decimal('69.79'))
# (138, 2, Decimal('36.89'))
# (139, 1, Decimal('59.86'))
# (139, 2, Decimal('53.87'))
# (140, 1, Decimal('59.87'))
# (140, 2, Decimal('23.95'))
# (141, 1, Decimal('65.82'))
# (141, 2, Decimal('61.87'))
# (142, 1, Decimal('36.87'))
# (142, 2, Decimal('37.90'))
# (143, 1, Decimal('50.88'))
# (143, 2, Decimal('32.92'))
# (144, 1, Decimal('89.79'))
# (144, 2, Decimal('99.81'))
# (145, 1, Decimal('34.91'))
# (145, 2, Decimal('72.82'))
# (146, 1, Decimal('74.84'))
# (146, 2, Decimal('51.89'))
# (147, 1, Decimal('46.88'))
# (147, 2, Decimal('78.80'))
# (148, 1, Decimal('100.77'))
# (148, 2, Decimal('110.78'))
# (149, 1, Decimal('62.86'))
# (149, 2, Decimal('53.89'))
# (150, 1, Decimal('34.91'))
# (150, 2, Decimal('59.87'))
# (151, 1, Decimal('50.87'))
# (151, 2, Decimal('30.88'))
# (152, 1, Decimal('49.88'))
# (152, 2, Decimal('23.93'))
# (153, 1, Decimal('48.86'))
# (153, 2, Decimal('45.90'))
# (154, 1, Decimal('59.84'))
# (154, 2, Decimal('50.89'))
# (155, 1, Decimal('62.86'))
# (155, 2, Decimal('43.90'))
# (156, 1, Decimal('32.91'))
# (156, 2, Decimal('56.86'))
# (157, 1, Decimal('63.84'))
# (157, 2, Decimal('43.87'))
# (158, 1, Decimal('63.82'))
# (158, 2, Decimal('51.88'))
# (159, 1, Decimal('17.93'))
# (159, 2, Decimal('40.90'))
# (160, 1, Decimal('54.87'))
# (160, 2, Decimal('51.86'))
# (161, 1, Decimal('57.86'))
# (161, 2, Decimal('36.90'))
# (162, 1, Decimal('31.91'))
# (162, 2, Decimal('27.92'))
# (163, 1, Decimal('41.89'))
# (163, 2, Decimal('80.82'))
# (164, 1, Decimal('29.94'))
# (164, 2, Decimal('34.91'))
# (165, 1, Decimal('31.91'))
# (165, 2, Decimal('49.89'))
# (166, 1, Decimal('59.87'))
# (166, 2, Decimal('61.86'))
# (167, 1, Decimal('59.84'))
# (167, 2, Decimal('48.87'))
# (168, 1, Decimal('72.83'))
# (168, 2, Decimal('56.85'))
# (169, 1, Decimal('35.92'))
# (169, 2, Decimal('50.88'))
# (170, 1, Decimal('44.91'))
# (170, 2, Decimal('64.86'))
# (171, 1, Decimal('36.91'))
# (171, 2, Decimal('67.84'))
# (172, 1, Decimal('54.86'))
# (172, 2, Decimal('78.84'))
# (173, 1, Decimal('56.88'))
# (173, 2, Decimal('54.85'))
# (174, 1, Decimal('45.88'))
# (174, 2, Decimal('35.93'))
# (175, 1, Decimal('34.89'))
# (175, 2, Decimal('63.87'))
# (176, 1, Decimal('111.78'))
# (176, 2, Decimal('39.90'))
# (177, 1, Decimal('31.88'))
# (177, 2, Decimal('39.89'))
# (178, 1, Decimal('108.81'))
# (178, 2, Decimal('85.80'))
# (179, 1, Decimal('77.83'))
# (179, 2, Decimal('42.91'))
# (180, 1, Decimal('64.86'))
# (180, 2, Decimal('30.92'))
# (181, 1, Decimal('84.85'))
# (181, 2, Decimal('82.82'))
# (182, 1, Decimal('55.86'))
# (182, 2, Decimal('36.90'))
# (183, 1, Decimal('34.91'))
# (183, 2, Decimal('40.87'))
# (184, 1, Decimal('29.90'))
# (184, 2, Decimal('50.90'))
# (185, 1, Decimal('59.87'))
# (185, 2, Decimal('19.93'))
# (186, 1, Decimal('61.84'))
# (186, 2, Decimal('49.87'))
# (187, 1, Decimal('40.92'))
# (187, 2, Decimal('110.81'))
# (188, 1, Decimal('25.93'))
# (188, 2, Decimal('66.82'))
# (189, 1, Decimal('55.87'))
# (189, 2, Decimal('31.92'))
# (190, 1, Decimal('43.89'))
# (190, 2, Decimal('58.86'))
# (191, 1, Decimal('42.89'))
# (191, 2, Decimal('23.93'))
# (192, 1, Decimal('59.88'))
# (192, 2, Decimal('37.90'))
# (193, 1, Decimal('53.88'))
# (193, 2, Decimal('51.89'))
# (194, 1, Decimal('36.91'))
# (194, 2, Decimal('37.93'))
# (195, 1, Decimal('37.92'))
# (195, 2, Decimal('48.89'))
# (196, 1, Decimal('58.88'))
# (196, 2, Decimal('69.81'))
# (197, 1, Decimal('70.83'))
# (197, 2, Decimal('62.85'))
# (198, 1, Decimal('80.82'))
# (198, 2, Decimal('43.86'))
# (199, 1, Decimal('46.87'))
# (199, 2, Decimal('48.89'))
# (200, 1, Decimal('72.86'))
# (200, 2, Decimal('53.88'))
# (201, 1, Decimal('26.92'))
# (201, 2, Decimal('64.86'))
# (202, 1, Decimal('54.85'))
# (202, 2, Decimal('48.89'))
# (203, 1, Decimal('25.93'))
# (203, 2, Decimal('61.88'))
# (204, 1, Decimal('69.85'))
# (204, 2, Decimal('64.84'))
# (205, 1, Decimal('31.91'))
# (205, 2, Decimal('48.91'))
# (206, 1, Decimal('49.90'))
# (206, 2, Decimal('76.83'))
# (207, 1, Decimal('34.90'))
# (207, 2, Decimal('84.82'))
# (208, 1, Decimal('37.88'))
# (208, 2, Decimal('48.87'))
# (209, 1, Decimal('66.85'))
# (209, 2, Decimal('80.86'))
# (210, 1, Decimal('46.90'))
# (210, 2, Decimal('87.80'))
# (211, 1, Decimal('37.90'))
# (211, 2, Decimal('108.77'))
# (212, 1, Decimal('30.93'))
# (212, 2, Decimal('60.87'))
# (213, 1, Decimal('48.88'))
# (213, 2, Decimal('61.85'))
# (214, 1, Decimal('31.91'))
# (214, 2, Decimal('71.83'))
# (215, 1, Decimal('17.92'))
# (215, 2, Decimal('63.84'))
# (216, 1, Decimal('37.89'))
# (216, 2, Decimal('52.89'))
# (217, 1, Decimal('44.90'))
# (217, 2, Decimal('41.89'))
# (218, 1, Decimal('26.91'))
# (218, 2, Decimal('40.91'))
# (219, 1, Decimal('50.89'))
# (219, 2, Decimal('49.86'))
# (220, 1, Decimal('39.89'))
# (220, 2, Decimal('69.86'))
# (221, 1, Decimal('83.84'))
# (221, 2, Decimal('43.89'))
# (222, 1, Decimal('23.94'))
# (222, 2, Decimal('47.90'))
# (223, 1, Decimal('34.92'))
# (223, 2, Decimal('42.92'))
# (224, 1, Decimal('39.88'))
# (224, 2, Decimal('36.90'))
# (225, 1, Decimal('53.90'))
# (225, 2, Decimal('57.86'))
# (226, 1, Decimal('66.85'))
# (226, 2, Decimal('20.94'))
# (227, 1, Decimal('38.90'))
# (227, 2, Decimal('39.88'))
# (228, 1, Decimal('37.89'))
# (228, 2, Decimal('48.86'))
# (229, 1, Decimal('43.90'))
# (229, 2, Decimal('49.85'))
# (230, 1, Decimal('49.87'))
# (230, 2, Decimal('68.82'))
# (231, 1, Decimal('44.87'))
# (231, 2, Decimal('43.90'))
# (232, 1, Decimal('33.93'))
# (232, 2, Decimal('52.84'))
# (233, 1, Decimal('50.88'))
# (233, 2, Decimal('38.89'))
# (234, 1, Decimal('40.89'))
# (234, 2, Decimal('65.86'))
# (235, 1, Decimal('48.89'))
# (235, 2, Decimal('40.88'))
# (236, 1, Decimal('71.81'))
# (236, 2, Decimal('94.80'))
# (237, 1, Decimal('38.89'))
# (237, 2, Decimal('99.80'))
# (238, 1, Decimal('63.86'))
# (238, 2, Decimal('22.95'))
# (239, 1, Decimal('54.85'))
# (239, 2, Decimal('53.87'))
# (240, 1, Decimal('51.90'))
# (240, 2, Decimal('54.87'))
# (241, 1, Decimal('55.83'))
# (241, 2, Decimal('54.85'))
# (242, 1, Decimal('67.86'))
# (242, 2, Decimal('60.85'))
# (243, 1, Decimal('32.89'))
# (243, 2, Decimal('44.88'))
# (244, 1, Decimal('63.87'))
# (244, 2, Decimal('58.83'))
# (245, 1, Decimal('68.84'))
# (245, 2, Decimal('34.90'))
# (246, 1, Decimal('43.91'))
# (246, 2, Decimal('32.91'))
# (247, 1, Decimal('64.87'))
# (247, 2, Decimal('23.94'))
# (248, 1, Decimal('10.94'))
# (248, 2, Decimal('26.93'))
# (249, 1, Decimal('51.90'))
# (249, 2, Decimal('36.91'))
# (250, 1, Decimal('31.90'))
# (250, 2, Decimal('22.95'))
# (251, 1, Decimal('32.90'))
# (251, 2, Decimal('67.85'))
# (252, 1, Decimal('30.91'))
# (252, 2, Decimal('27.89'))
# (253, 1, Decimal('43.91'))
# (253, 2, Decimal('72.83'))
# (254, 1, Decimal('61.83'))
# (254, 2, Decimal('45.87'))
# (255, 1, Decimal('34.90'))
# (255, 2, Decimal('35.92'))
# (256, 1, Decimal('39.90'))
# (256, 2, Decimal('57.85'))
# (257, 1, Decimal('57.85'))
# (257, 2, Decimal('84.81'))
# (258, 1, Decimal('52.89'))
# (258, 2, Decimal('57.87'))
# (259, 1, Decimal('67.87'))
# (259, 2, Decimal('86.83'))
# (260, 1, Decimal('67.83'))
# (260, 2, Decimal('45.87'))
# (261, 1, Decimal('47.88'))
# (261, 2, Decimal('42.90'))
# (262, 1, Decimal('63.84'))
# (262, 2, Decimal('50.89'))
# (263, 1, Decimal('43.88'))
# (263, 2, Decimal('72.85'))
# (264, 1, Decimal('79.83'))
# (264, 2, Decimal('18.92'))
# (265, 1, Decimal('53.87'))
# (265, 2, Decimal('78.85'))
# (266, 1, Decimal('65.85'))
# (266, 2, Decimal('47.89'))
# (267, 1, Decimal('72.83'))
# (267, 2, Decimal('69.84'))
# (268, 1, Decimal('17.95'))
# (268, 2, Decimal('78.84'))
# (269, 1, Decimal('61.87'))
# (269, 2, Decimal('34.92'))
# (270, 1, Decimal('42.89'))
# (270, 2, Decimal('32.92'))
# (271, 1, Decimal('32.90'))
# (271, 2, Decimal('23.94'))
# (272, 1, Decimal('14.96'))
# (272, 2, Decimal('50.91'))
# (273, 1, Decimal('80.85'))
# (273, 2, Decimal('49.87'))
# (274, 1, Decimal('52.87'))
# (274, 2, Decimal('63.86'))
# (275, 1, Decimal('33.91'))
# (275, 2, Decimal('58.84'))
# (276, 1, Decimal('39.90'))
# (276, 2, Decimal('54.87'))
# (277, 1, Decimal('48.90'))
# (277, 2, Decimal('59.86'))
# (278, 1, Decimal('40.88'))
# (278, 2, Decimal('30.91'))
# (279, 1, Decimal('68.86'))
# (279, 2, Decimal('45.90'))
# (280, 1, Decimal('63.87'))
# (280, 2, Decimal('39.90'))
# (281, 1, Decimal('9.96'))
# (281, 2, Decimal('22.94'))
# (282, 1, Decimal('26.93'))
# (282, 2, Decimal('52.87'))
# (283, 1, Decimal('35.89'))
# (283, 2, Decimal('32.88'))
# (284, 1, Decimal('72.85'))
# (284, 2, Decimal('35.93'))
# (285, 1, Decimal('74.87'))
# (285, 2, Decimal('42.90'))
# (286, 1, Decimal('40.88'))
# (286, 2, Decimal('55.88'))
# (287, 1, Decimal('26.94'))
# (287, 2, Decimal('53.84'))
# (288, 1, Decimal('29.91'))
# (288, 2, Decimal('22.90'))
# (289, 1, Decimal('24.92'))
# (289, 2, Decimal('79.84'))
# (290, 1, Decimal('39.89'))
# (290, 2, Decimal('40.89'))
# (291, 1, Decimal('26.94'))
# (291, 2, Decimal('46.89'))
# (292, 1, Decimal('77.85'))
# (292, 2, Decimal('24.93'))
# (293, 1, Decimal('61.89'))
# (293, 2, Decimal('45.90'))
# (294, 1, Decimal('45.91'))
# (294, 2, Decimal('59.86'))
# (295, 1, Decimal('65.87'))
# (295, 2, Decimal('59.85'))
# (296, 1, Decimal('47.89'))
# (296, 2, Decimal('55.88'))
# (297, 1, Decimal('63.85'))
# (297, 2, Decimal('35.89'))
# (298, 1, Decimal('42.90'))
# (298, 2, Decimal('35.89'))
# (299, 1, Decimal('48.88'))
# (299, 2, Decimal('35.91'))
# (300, 1, Decimal('82.84'))
# (300, 2, Decimal('40.90'))
# (301, 1, Decimal('20.96'))
# (301, 2, Decimal('50.89'))
# (302, 1, Decimal('59.89'))
# (302, 2, Decimal('53.85'))
# (303, 1, Decimal('36.91'))
# (303, 2, Decimal('33.90'))
# (304, 1, Decimal('45.89'))
# (304, 2, Decimal('33.92'))
# (305, 1, Decimal('37.93'))
# (305, 2, Decimal('49.87'))
# (306, 1, Decimal('58.86'))
# (306, 2, Decimal('60.86'))
# (307, 1, Decimal('68.84'))
# (307, 2, Decimal('23.96'))
# (308, 1, Decimal('57.88'))
# (308, 2, Decimal('23.93'))
# (309, 1, Decimal('37.89'))
# (309, 2, Decimal('75.86'))
# (310, 1, Decimal('34.93'))
# (310, 2, Decimal('33.94'))
# (311, 1, Decimal('26.95'))
# (311, 2, Decimal('53.90'))
# (312, 1, Decimal('65.85'))
# (312, 2, Decimal('15.95'))
# (313, 1, Decimal('18.95'))
# (313, 2, Decimal('44.89'))
# (314, 1, Decimal('33.89'))
# (314, 2, Decimal('79.82'))
# (315, 1, Decimal('33.93'))
# (315, 2, Decimal('33.93'))
# (316, 1, Decimal('37.91'))
# (316, 2, Decimal('42.90'))
# (317, 1, Decimal('61.85'))
# (317, 2, Decimal('34.91'))
# (318, 1, Decimal('17.96'))
# (318, 2, Decimal('9.97'))
# (319, 1, Decimal('50.90'))
# (319, 2, Decimal('42.89'))
# (320, 1, Decimal('5.96'))
# (320, 2, Decimal('41.89'))
# (321, 1, Decimal('39.92'))
# (321, 2, Decimal('53.91'))
# (322, 1, Decimal('40.91'))
# (322, 2, Decimal('40.90'))
# (323, 1, Decimal('46.86'))
# (323, 2, Decimal('44.89'))
# (324, 1, Decimal('53.88'))
# (324, 2, Decimal('41.90'))
# (325, 1, Decimal('26.94'))
# (325, 2, Decimal('45.88'))
# (326, 1, Decimal('28.94'))
# (326, 2, Decimal('35.88'))
# (327, 1, Decimal('48.87'))
# (327, 2, Decimal('25.94'))
# (328, 1, Decimal('41.89'))
# (328, 2, Decimal('23.94'))
# (329, 1, Decimal('61.88'))
# (329, 2, Decimal('36.89'))
# (330, 1, Decimal('28.91'))
# (330, 2, Decimal('31.91'))
# (331, 1, Decimal('69.84'))
# (331, 2, Decimal('35.94'))
# (332, 1, Decimal('41.89'))
# (332, 2, Decimal('65.85'))
# (333, 1, Decimal('33.92'))
# (333, 2, Decimal('55.86'))
# (334, 1, Decimal('61.85'))
# (334, 2, Decimal('46.90'))
# (335, 1, Decimal('44.88'))
# (335, 2, Decimal('28.90'))
# (336, 1, Decimal('34.93'))
# (336, 2, Decimal('58.85'))
# (337, 1, Decimal('51.88'))
# (337, 2, Decimal('59.88'))
# (338, 1, Decimal('33.90'))
# (338, 2, Decimal('44.90'))
# (339, 1, Decimal('43.87'))
# (339, 2, Decimal('51.89'))
# (340, 1, Decimal('44.88'))
# (340, 2, Decimal('38.89'))
# (341, 1, Decimal('41.92'))
# (341, 2, Decimal('61.86'))
# (342, 1, Decimal('50.85'))
# (342, 2, Decimal('79.83'))
# (343, 1, Decimal('43.91'))
# (343, 2, Decimal('62.86'))
# (344, 1, Decimal('12.95'))
# (344, 2, Decimal('51.89'))
# (345, 1, Decimal('51.91'))
# (345, 2, Decimal('52.88'))
# (346, 1, Decimal('65.87'))
# (346, 2, Decimal('79.83'))
# (347, 1, Decimal('58.88'))
# (347, 2, Decimal('83.82'))
# (348, 1, Decimal('62.87'))
# (348, 2, Decimal('81.79'))
# (349, 1, Decimal('70.83'))
# (349, 2, Decimal('62.89'))
# (350, 1, Decimal('21.90'))
# (350, 2, Decimal('41.89'))
# (351, 1, Decimal('42.88'))
# (351, 2, Decimal('44.89'))
# (352, 1, Decimal('62.86'))
# (352, 2, Decimal('33.92'))
# (353, 1, Decimal('17.95'))
# (353, 2, Decimal('47.88'))
# (354, 1, Decimal('81.81'))
# (354, 2, Decimal('43.86'))
# (355, 1, Decimal('36.90'))
# (355, 2, Decimal('31.91'))
# (356, 1, Decimal('53.83'))
# (356, 2, Decimal('62.88'))
# (357, 1, Decimal('40.88'))
# (357, 2, Decimal('39.89'))
# (358, 1, Decimal('56.85'))
# (358, 2, Decimal('18.95'))
# (359, 1, Decimal('38.88'))
# (359, 2, Decimal('46.90'))
# (360, 1, Decimal('64.85'))
# (360, 2, Decimal('79.83'))
# (361, 1, Decimal('36.86'))
# (361, 2, Decimal('52.85'))
# (362, 1, Decimal('80.82'))
# (362, 2, Decimal('59.87'))
# (363, 1, Decimal('68.88'))
# (363, 2, Decimal('70.84'))
# (364, 1, Decimal('36.90'))
# (364, 2, Decimal('52.88'))
# (365, 1, Decimal('55.88'))
# (365, 2, Decimal('36.91'))
# (366, 1, Decimal('87.80'))
# (366, 2, Decimal('57.84'))
# (367, 1, Decimal('47.91'))
# (367, 2, Decimal('49.89'))
# (368, 1, Decimal('74.83'))
# (368, 2, Decimal('64.86'))
# (369, 1, Decimal('26.90'))
# (369, 2, Decimal('42.89'))
# (370, 1, Decimal('35.91'))
# (370, 2, Decimal('34.90'))
# (371, 1, Decimal('75.81'))
# (371, 2, Decimal('47.90'))
# (372, 1, Decimal('66.81'))
# (372, 2, Decimal('85.87'))
# (373, 1, Decimal('89.81'))
# (373, 2, Decimal('66.85'))
# (374, 1, Decimal('32.91'))
# (374, 2, Decimal('65.84'))
# (375, 1, Decimal('55.88'))
# (375, 2, Decimal('32.92'))
# (376, 1, Decimal('79.80'))
# (376, 2, Decimal('29.93'))
# (377, 1, Decimal('50.84'))
# (377, 2, Decimal('42.90'))
# (378, 1, Decimal('37.90'))
# (378, 2, Decimal('32.92'))
# (379, 1, Decimal('64.86'))
# (379, 2, Decimal('31.93'))
# (380, 1, Decimal('91.78'))
# (380, 2, Decimal('40.87'))
# (381, 1, Decimal('35.88'))
# (381, 2, Decimal('63.80'))
# (382, 1, Decimal('43.90'))
# (382, 2, Decimal('41.88'))
# (383, 1, Decimal('55.86'))
# (383, 2, Decimal('37.89'))
# (384, 1, Decimal('32.93'))
# (384, 2, Decimal('44.86'))
# (385, 1, Decimal('57.83'))
# (385, 2, Decimal('35.93'))
# (386, 1, Decimal('56.84'))
# (386, 2, Decimal('52.88'))
# (387, 1, Decimal('30.91'))
# (387, 2, Decimal('48.87'))
# (388, 1, Decimal('37.91'))
# (388, 2, Decimal('76.81'))
# (389, 1, Decimal('71.85'))
# (389, 2, Decimal('47.90'))
# (390, 1, Decimal('72.84'))
# (390, 2, Decimal('69.85'))
# (391, 1, Decimal('51.84'))
# (391, 2, Decimal('27.91'))
# (392, 1, Decimal('35.90'))
# (392, 2, Decimal('55.87'))
# (393, 1, Decimal('46.89'))
# (393, 2, Decimal('68.82'))
# (394, 1, Decimal('37.90'))
# (394, 2, Decimal('39.90'))
# (395, 1, Decimal('45.86'))
# (395, 2, Decimal('11.95'))
# (396, 1, Decimal('26.93'))
# (396, 2, Decimal('78.81'))
# (397, 1, Decimal('48.88'))
# (397, 2, Decimal('55.84'))
# (398, 1, Decimal('26.94'))
# (398, 2, Decimal('46.91'))
# (399, 1, Decimal('26.93'))
# (399, 2, Decimal('46.89'))
# (400, 1, Decimal('35.91'))
# (400, 2, Decimal('69.85'))
# (401, 1, Decimal('32.89'))
# (401, 2, Decimal('29.92'))
# (402, 1, Decimal('19.95'))
# (402, 2, Decimal('57.86'))
# (403, 1, Decimal('80.84'))
# (403, 2, Decimal('81.83'))
# (404, 1, Decimal('78.82'))
# (404, 2, Decimal('54.89'))
# (405, 1, Decimal('56.82'))
# (405, 2, Decimal('44.88'))
# (406, 1, Decimal('53.88'))
# (406, 2, Decimal('67.81'))
# (407, 1, Decimal('50.87'))
# (407, 2, Decimal('53.87'))
# (408, 1, Decimal('41.89'))
# (408, 2, Decimal('61.84'))
# (409, 1, Decimal('47.89'))
# (409, 2, Decimal('49.89'))
# (410, 1, Decimal('101.76'))
# (410, 2, Decimal('65.86'))
# (411, 1, Decimal('31.89'))
# (411, 2, Decimal('41.87'))
# (412, 1, Decimal('45.90'))
# (412, 2, Decimal('28.93'))
# (413, 1, Decimal('31.90'))
# (413, 2, Decimal('33.91'))
# (414, 1, Decimal('63.86'))
# (414, 2, Decimal('32.91'))
# (415, 1, Decimal('34.91'))
# (415, 2, Decimal('53.87'))
# (416, 1, Decimal('78.83'))
# (416, 2, Decimal('34.89'))
# (417, 1, Decimal('63.86'))
# (417, 2, Decimal('27.92'))
# (418, 1, Decimal('50.83'))
# (418, 2, Decimal('56.87'))
# (419, 1, Decimal('49.87'))
# (419, 2, Decimal('36.89'))
# (420, 1, Decimal('22.93'))
# (420, 2, Decimal('51.87'))
# (421, 1, Decimal('70.86'))
# (421, 2, Decimal('46.89'))
# (422, 1, Decimal('48.89'))
# (422, 2, Decimal('47.86'))
# (423, 1, Decimal('59.86'))
# (423, 2, Decimal('60.88'))
# (424, 1, Decimal('47.89'))
# (424, 2, Decimal('61.82'))
# (425, 1, Decimal('48.87'))
# (425, 2, Decimal('49.88'))
# (426, 1, Decimal('68.86'))
# (426, 2, Decimal('56.88'))
# (427, 1, Decimal('60.87'))
# (427, 2, Decimal('46.90'))
# (428, 1, Decimal('47.89'))
# (428, 2, Decimal('25.92'))
# (429, 1, Decimal('18.95'))
# (429, 2, Decimal('59.89'))
# (430, 1, Decimal('53.88'))
# (430, 2, Decimal('17.92'))
# (431, 1, Decimal('39.90'))
# (431, 2, Decimal('52.88'))
# (432, 1, Decimal('52.90'))
# (432, 2, Decimal('40.90'))
# (433, 1, Decimal('64.87'))
# (433, 2, Decimal('48.90'))
# (434, 1, Decimal('42.89'))
# (434, 2, Decimal('79.85'))
# (435, 1, Decimal('54.85'))
# (435, 2, Decimal('23.92'))
# (436, 1, Decimal('51.89'))
# (436, 2, Decimal('74.84'))
# (437, 1, Decimal('25.93'))
# (437, 2, Decimal('59.87'))
# (438, 1, Decimal('48.89'))
# (438, 2, Decimal('72.81'))
# (439, 1, Decimal('57.83'))
# (439, 2, Decimal('79.84'))
# (440, 1, Decimal('46.89'))
# (440, 2, Decimal('36.90'))
# (441, 1, Decimal('48.89'))
# (441, 2, Decimal('58.84'))
# (442, 1, Decimal('52.85'))
# (442, 2, Decimal('51.86'))
# (443, 1, Decimal('52.88'))
# (443, 2, Decimal('40.91'))
# (444, 1, Decimal('39.88'))
# (444, 2, Decimal('65.84'))
# (445, 1, Decimal('59.87'))
# (445, 2, Decimal('36.89'))
# (446, 1, Decimal('47.88'))
# (446, 2, Decimal('61.84'))
# (447, 1, Decimal('61.86'))
# (447, 2, Decimal('47.87'))
# (448, 1, Decimal('50.90'))
# (448, 2, Decimal('76.83'))
# (449, 1, Decimal('30.93'))
# (449, 2, Decimal('49.90'))
# (450, 1, Decimal('53.85'))
# (450, 2, Decimal('31.90'))
# (451, 1, Decimal('62.84'))
# (451, 2, Decimal('58.86'))
# (452, 1, Decimal('46.83'))
# (452, 2, Decimal('52.88'))
# (453, 1, Decimal('48.89'))
# (453, 2, Decimal('62.88'))
# (454, 1, Decimal('53.87'))
# (454, 2, Decimal('89.81'))
# (455, 1, Decimal('47.88'))
# (455, 2, Decimal('37.90'))
# (456, 1, Decimal('63.85'))
# (456, 2, Decimal('31.91'))
# (457, 1, Decimal('64.82'))
# (457, 2, Decimal('41.91'))
# (458, 1, Decimal('17.94'))
# (458, 2, Decimal('48.87'))
# (459, 1, Decimal('108.78'))
# (459, 2, Decimal('74.85'))
# (460, 1, Decimal('46.90'))
# (460, 2, Decimal('50.89'))
# (461, 1, Decimal('33.90'))
# (461, 2, Decimal('56.83'))
# (462, 1, Decimal('97.79'))
# (462, 2, Decimal('54.90'))
# (463, 1, Decimal('43.85'))
# (463, 2, Decimal('45.91'))
# (464, 1, Decimal('45.92'))
# (464, 2, Decimal('21.94'))
# (465, 1, Decimal('43.90'))
# (465, 2, Decimal('24.94'))
# (466, 1, Decimal('62.88'))
# (466, 2, Decimal('38.90'))
# (467, 1, Decimal('67.85'))
# (467, 2, Decimal('66.87'))
# (468, 1, Decimal('68.83'))
# (468, 2, Decimal('85.83'))
# (469, 1, Decimal('96.81'))
# (469, 2, Decimal('61.84'))
# (470, 1, Decimal('89.82'))
# (470, 2, Decimal('67.87'))
# (471, 1, Decimal('63.85'))
# (471, 2, Decimal('42.89'))
# (472, 1, Decimal('62.86'))
# (472, 2, Decimal('68.88'))
# (473, 1, Decimal('35.88'))
# (473, 2, Decimal('86.81'))
# (474, 1, Decimal('53.85'))
# (474, 2, Decimal('38.90'))
# (475, 1, Decimal('64.85'))
# (475, 2, Decimal('32.93'))
# (476, 1, Decimal('44.88'))
# (476, 2, Decimal('42.92'))
# (477, 1, Decimal('45.91'))
# (477, 2, Decimal('60.88'))
# (478, 1, Decimal('38.91'))
# (478, 2, Decimal('47.90'))
# (479, 1, Decimal('39.89'))
# (479, 2, Decimal('94.82'))
# (480, 1, Decimal('25.93'))
# (480, 2, Decimal('57.88'))
# (481, 1, Decimal('56.86'))
# (481, 2, Decimal('52.86'))
# (482, 1, Decimal('39.92'))
# (482, 2, Decimal('85.82'))
# (483, 1, Decimal('48.92'))
# (483, 2, Decimal('32.91'))
# (484, 1, Decimal('57.87'))
# (484, 2, Decimal('70.86'))
# (485, 1, Decimal('54.86'))
# (485, 2, Decimal('57.86'))
# (486, 1, Decimal('40.91'))
# (486, 2, Decimal('59.86'))
# (487, 1, Decimal('66.88'))
# (487, 2, Decimal('52.86'))
# (488, 1, Decimal('29.92'))
# (488, 2, Decimal('65.86'))
# (489, 1, Decimal('50.89'))
# (489, 2, Decimal('40.92'))
# (490, 1, Decimal('53.89'))
# (490, 2, Decimal('51.89'))
# (491, 1, Decimal('49.89'))
# (491, 2, Decimal('70.86'))
# (492, 1, Decimal('24.94'))
# (492, 2, Decimal('37.91'))
# (493, 1, Decimal('61.86'))
# (493, 2, Decimal('42.92'))
# (494, 1, Decimal('40.89'))
# (494, 2, Decimal('94.81'))
# (495, 1, Decimal('60.88'))
# (495, 2, Decimal('49.88'))
# (496, 1, Decimal('50.88'))
# (496, 2, Decimal('31.93'))
# (497, 1, Decimal('65.85'))
# (497, 2, Decimal('55.88'))
# (498, 1, Decimal('62.84'))
# (498, 2, Decimal('19.92'))
# (499, 1, Decimal('72.84'))
# (499, 2, Decimal('47.87'))
# (500, 1, Decimal('43.87'))
# (500, 2, Decimal('52.88'))
# (501, 1, Decimal('37.91'))
# (501, 2, Decimal('48.90'))
# (502, 1, Decimal('69.83'))
# (502, 2, Decimal('60.87'))
# (503, 1, Decimal('55.84'))
# (503, 2, Decimal('43.88'))
# (504, 1, Decimal('56.89'))
# (504, 2, Decimal('60.86'))
# (505, 1, Decimal('44.89'))
# (505, 2, Decimal('46.92'))
# (506, 1, Decimal('47.89'))
# (506, 2, Decimal('75.83'))
# (507, 1, Decimal('42.89'))
# (507, 2, Decimal('46.88'))
# (508, 1, Decimal('45.91'))
# (508, 2, Decimal('75.86'))
# (509, 1, Decimal('45.92'))
# (509, 2, Decimal('40.90'))
# (510, 1, Decimal('39.91'))
# (510, 2, Decimal('62.86'))
# (511, 1, Decimal('53.86'))
# (511, 2, Decimal('38.92'))
# (512, 1, Decimal('53.86'))
# (512, 2, Decimal('61.88'))
# (513, 1, Decimal('69.85'))
# (513, 2, Decimal('73.85'))
# (514, 1, Decimal('41.87'))
# (514, 2, Decimal('27.92'))
# (515, 1, Decimal('37.93'))
# (515, 2, Decimal('72.81'))
# (516, 1, Decimal('53.86'))
# (516, 2, Decimal('38.90'))
# (517, 1, Decimal('51.89'))
# (517, 2, Decimal('48.87'))
# (518, 1, Decimal('46.89'))
# (518, 2, Decimal('61.86'))
# (519, 1, Decimal('31.93'))
# (519, 2, Decimal('67.85'))
# (520, 1, Decimal('78.80'))
# (520, 2, Decimal('48.89'))
# (521, 1, Decimal('29.91'))
# (521, 2, Decimal('50.86'))
# (522, 1, Decimal('58.88'))
# (522, 2, Decimal('102.80'))
# (523, 1, Decimal('56.89'))
# (523, 2, Decimal('30.91'))
# (524, 1, Decimal('32.93'))
# (524, 2, Decimal('48.90'))
# (525, 1, Decimal('27.90'))
# (525, 2, Decimal('40.92'))
# (526, 1, Decimal('106.80'))
# (526, 2, Decimal('101.78'))
# (527, 1, Decimal('63.83'))
# (527, 2, Decimal('17.93'))
# (528, 1, Decimal('43.90'))
# (528, 2, Decimal('49.90'))
# (529, 1, Decimal('46.89'))
# (529, 2, Decimal('68.83'))
# (530, 1, Decimal('41.88'))
# (530, 2, Decimal('33.90'))
# (531, 1, Decimal('45.92'))
# (531, 2, Decimal('64.85'))
# (532, 1, Decimal('68.86'))
# (532, 2, Decimal('80.83'))
# (533, 1, Decimal('82.82'))
# (533, 2, Decimal('49.88'))
# (534, 1, Decimal('35.90'))
# (534, 2, Decimal('45.88'))
# (535, 1, Decimal('70.82'))
# (535, 2, Decimal('51.90'))
# (536, 1, Decimal('74.85'))
# (536, 2, Decimal('34.92'))
# (537, 1, Decimal('50.87'))
# (537, 2, Decimal('47.89'))
# (538, 1, Decimal('56.84'))
# (538, 2, Decimal('52.89'))
# (539, 1, Decimal('26.92'))
# (539, 2, Decimal('57.88'))
# (540, 1, Decimal('38.92'))
# (540, 2, Decimal('73.84'))
# (541, 1, Decimal('50.90'))
# (541, 2, Decimal('44.88'))
# (542, 1, Decimal('33.93'))
# (542, 2, Decimal('50.91'))
# (543, 1, Decimal('26.90'))
# (543, 2, Decimal('46.90'))
# (544, 1, Decimal('50.87'))
# (544, 2, Decimal('41.93'))
# (545, 1, Decimal('38.90'))
# (545, 2, Decimal('45.91'))
# (546, 1, Decimal('52.86'))
# (546, 2, Decimal('41.90'))
# (547, 1, Decimal('36.91'))
# (547, 2, Decimal('50.89'))
# (548, 1, Decimal('32.92'))
# (548, 2, Decimal('30.92'))
# (549, 1, Decimal('17.95'))
# (549, 2, Decimal('44.89'))
# (550, 1, Decimal('86.82'))
# (550, 2, Decimal('64.87'))
# (551, 1, Decimal('23.91'))
# (551, 2, Decimal('51.88'))
# (552, 1, Decimal('32.93'))
# (552, 2, Decimal('56.87'))
# (553, 1, Decimal('49.90'))
# (553, 2, Decimal('52.87'))
# (554, 1, Decimal('56.87'))
# (554, 2, Decimal('38.93'))
# (555, 1, Decimal('32.92'))
# (555, 2, Decimal('41.91'))
# (556, 1, Decimal('31.92'))
# (556, 2, Decimal('40.90'))
# (557, 1, Decimal('26.88'))
# (557, 2, Decimal('36.90'))
# (558, 1, Decimal('51.85'))
# (558, 2, Decimal('83.87'))
# (559, 1, Decimal('69.83'))
# (559, 2, Decimal('40.89'))
# (560, 1, Decimal('67.84'))
# (560, 2, Decimal('61.87'))
# (561, 1, Decimal('54.84'))
# (561, 2, Decimal('31.91'))
# (562, 1, Decimal('40.91'))
# (562, 2, Decimal('56.87'))
# (563, 1, Decimal('27.90'))
# (563, 2, Decimal('71.83'))
# (564, 1, Decimal('18.93'))
# (564, 2, Decimal('63.85'))
# (565, 1, Decimal('62.84'))
# (565, 2, Decimal('55.89'))
# (566, 1, Decimal('59.84'))
# (566, 2, Decimal('70.84'))
# (567, 1, Decimal('37.92'))
# (567, 2, Decimal('47.88'))
# (568, 1, Decimal('28.91'))
# (568, 2, Decimal('37.88'))
# (569, 1, Decimal('61.88'))
# (569, 2, Decimal('51.85'))
# (570, 1, Decimal('32.89'))
# (570, 2, Decimal('58.86'))
# (571, 1, Decimal('65.87'))
# (571, 2, Decimal('41.91'))
# (572, 1, Decimal('55.85'))
# (572, 2, Decimal('44.91'))
# (573, 1, Decimal('58.83'))
# (573, 2, Decimal('58.89'))
# (574, 1, Decimal('84.79'))
# (574, 2, Decimal('23.94'))
# (575, 1, Decimal('40.91'))
# (575, 2, Decimal('68.85'))
# (576, 1, Decimal('67.83'))
# (576, 2, Decimal('67.85'))
# (577, 1, Decimal('50.90'))
# (577, 2, Decimal('60.84'))
# (578, 1, Decimal('44.89'))
# (578, 2, Decimal('50.90'))
# (579, 1, Decimal('39.88'))
# (579, 2, Decimal('71.85'))
# (580, 1, Decimal('58.87'))
# (580, 2, Decimal('39.87'))
# (581, 1, Decimal('48.88'))
# (581, 2, Decimal('48.87'))
# (582, 1, Decimal('59.86'))
# (582, 2, Decimal('52.90'))
# (583, 1, Decimal('49.89'))
# (583, 2, Decimal('67.88'))
# (584, 1, Decimal('36.89'))
# (584, 2, Decimal('77.84'))
# (585, 1, Decimal('56.89'))
# (585, 2, Decimal('60.87'))
# (586, 1, Decimal('21.92'))
# (586, 2, Decimal('28.91'))
# (587, 1, Decimal('24.93'))
# (587, 2, Decimal('77.83'))
# (588, 1, Decimal('49.86'))
# (588, 2, Decimal('57.87'))
# (589, 1, Decimal('54.89'))
# (589, 2, Decimal('63.86'))
# (590, 1, Decimal('57.88'))
# (590, 2, Decimal('50.88'))
# (591, 1, Decimal('79.84'))
# (591, 2, Decimal('54.89'))
# (592, 1, Decimal('70.84'))
# (592, 2, Decimal('40.87'))
# (593, 1, Decimal('49.89'))
# (593, 2, Decimal('51.87'))
# (594, 1, Decimal('67.87'))
# (594, 2, Decimal('40.90'))
# (595, 1, Decimal('66.84'))
# (595, 2, Decimal('43.87'))
# (596, 1, Decimal('44.85'))
# (596, 2, Decimal('28.93'))
# (597, 1, Decimal('49.86'))
# (597, 2, Decimal('37.91'))
# (598, 1, Decimal('43.90'))
# (598, 2, Decimal('39.88'))
# (599, 1, Decimal('28.92'))
# (599, 2, Decimal('49.90'))
# PostgreSQL connection is closed
