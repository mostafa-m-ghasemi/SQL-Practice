# %%
import psycopg2
import os
from dotenv import load_dotenv
load_dotenv()
db_password = os.getenv("DB_PASSWORD")
connection = None

try:
    connection = psycopg2.connect(
        user="postgres",
        password=db_password,
        host="127.0.0.1",
        port="5432",
        database="dvdrental",
    )

    cursor = connection.cursor()
    query = """
            select date(payment_date), count(amount), sum(amount) from payment
            group by date(payment_date)
            order by date(payment_date)
            """
    cursor.execute(query)
    rows = cursor.fetchall()
    for row in rows:
        print(row)
except Exception as error:
    print(error)
finally:
    if connection:
        cursor.close()
        connection.close()
        print("PostgreSQL connection is closed")
# Out:
# (datetime.date(2007, 2, 14), 27, Decimal('116.73'))
# (datetime.date(2007, 2, 15), 308, Decimal('1188.92'))
# (datetime.date(2007, 2, 16), 282, Decimal('1154.18'))
# (datetime.date(2007, 2, 17), 283, Decimal('1188.17'))
# (datetime.date(2007, 2, 18), 302, Decimal('1275.98'))
# (datetime.date(2007, 2, 19), 310, Decimal('1290.90'))
# (datetime.date(2007, 2, 20), 291, Decimal('1219.09'))
# (datetime.date(2007, 2, 21), 213, Decimal('917.87'))
# (datetime.date(2007, 3, 1), 676, Decimal('2808.24'))
# (datetime.date(2007, 3, 2), 595, Decimal('2550.05'))
# (datetime.date(2007, 3, 16), 72, Decimal('299.28'))
# (datetime.date(2007, 3, 17), 584, Decimal('2442.16'))
# (datetime.date(2007, 3, 18), 624, Decimal('2701.76'))
# (datetime.date(2007, 3, 19), 631, Decimal('2617.69'))
# (datetime.date(2007, 3, 20), 611, Decimal('2669.89'))
# (datetime.date(2007, 3, 21), 673, Decimal('2868.27'))
# (datetime.date(2007, 3, 22), 621, Decimal('2586.79'))
# (datetime.date(2007, 3, 23), 557, Decimal('2342.43'))
# (datetime.date(2007, 4, 5), 64, Decimal('273.36'))
# (datetime.date(2007, 4, 6), 486, Decimal('2077.14'))
# (datetime.date(2007, 4, 7), 472, Decimal('1984.28'))
# (datetime.date(2007, 4, 8), 516, Decimal('2227.84'))
# (datetime.date(2007, 4, 9), 514, Decimal('2067.86'))
# (datetime.date(2007, 4, 10), 482, Decimal('1973.18'))
# (datetime.date(2007, 4, 11), 468, Decimal('1940.32'))
# (datetime.date(2007, 4, 12), 452, Decimal('1930.48'))
# (datetime.date(2007, 4, 26), 79, Decimal('347.21'))
# (datetime.date(2007, 4, 27), 643, Decimal('2673.57'))
# (datetime.date(2007, 4, 28), 627, Decimal('2622.73'))
# (datetime.date(2007, 4, 29), 640, Decimal('2717.60'))
# (datetime.date(2007, 4, 30), 1311, Decimal('5723.89'))
# (datetime.date(2007, 5, 14), 182, Decimal('514.18'))
# PostgreSQL connection is closed
